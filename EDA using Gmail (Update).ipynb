# %%
#installing mailbox module

# !pip install mailbox
# Out:
# Requirement already satisfied: mailbox in c:\users\victor joy\anaconda3\lib\site-packages (0.4)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import mailbox  # mailbox is a python module that helps access and manipulate files of difeerent mailbox formats like mbox, MailDi and, MH.

# %%
# path to the mbox file on my local machine
# r" is used to prevent Unicode error from \U 

mboxfile = r"C:\Users\VICTOR JOY\Downloads\takeout-20201104T005831Z-001\Takeout\Mail\All mail Including Spam and Trash.mbox"
mbox = mailbox.mbox(mboxfile)
mbox

# %%
# mailbox interface dictionary-like meaning it contains key-value pairs.
# here we search for all the keys in the mbox file we collected

for key in mbox[0].keys():
    print(key)
# Out:
# X-GM-THRID
# X-Gmail-Labels
# Delivered-To
# Received
# X-Google-Smtp-Source
# X-Received
# ARC-Seal
# ARC-Message-Signature
# ARC-Authentication-Results
# Return-Path
# Received
# Received-SPF
# Authentication-Results
# DKIM-Signature
# To
# From
# Reply-To
# Subject
# Message-ID
# List-Unsubscribe
# Feedback-ID
# MIME-Version
# Content-Type
# Date

# %%
import csv

# %%
# converting the mailbox into a csv file
# csv file name = mailbox.csv
# encoding = utf-8 is used to prevent unicode errors. Most webpages use utf-8 to represent unicodes, meaning there are unicodes in our mail, without this, our code wouls give errors
# we're using a with statement because we want to do something to the data

with open('mailbox.csv', 'w', encoding="utf-8") as outputfile:  # output file is used to refer to the file objects
  writer = csv.writer(outputfile) #csv writer reads and writes documents in dictionary form
  writer.writerow(['subject','from','date','to','label','thread'])
    
    
  for message in mbox:
    writer.writerow([message['subject'], message['from'],  message['date'], message['to'],  message['X-Gmail-Labels'], message['X-GM-THRID']])

# %%
#reading the csv file and naming features/columns

dfs = pd.read_csv('mailbox.csv', names=['subject', 'from', 'date', 'to', 'label', 'thread'])

# %%
dfs.dtypes
# Out:
# subject    object
# from       object
# date       object
# to         object
# label      object
# thread     object
# dtype: object

# %%
#date is of type "object" but we want to change it to type "date-time" so we can have a proper analysis of our e-mail data

dfs['date'] = dfs['date'].apply(lambda x: pd.to_datetime(x, errors='coerce', utc=True))

# %%
'''errors{‘ignore’, ‘raise’, ‘coerce’}, default ‘raise’

If ‘raise’, then invalid parsing will raise an exception.
If ‘coerce’, then invalid parsing will be set as NaN.
If ‘ignore’, then invalid parsing will return the input.'''


'''utc: Boolean value, Returns time in UTC if True.'''

# %%
dfs.dtypes
# Out:
# subject                 object
# from                    object
# date       datetime64[ns, UTC]
# to                      object
# label                   object
# thread                  object
# dtype: object

# %%
# find the Nan values from date

dfs = dfs[dfs['date'].notna()]

# %%
# saving the dataframe into a csv file

dfs.to_csv('gmail.csv')

# %% [markdown]
# # DESCRIPTIVE STATISTICS

# %%
dfs
# Out:
#                                                  subject  \
# 1      =?UTF-8?Q?Joy,_Save_=E2=82=A650,000_Off_Your_S...
# 2      =?utf-8?Q?19=20Gifts=20for=20Your=20=27Emily=2...
# 3      =?utf-8?Q?=F0=9F=93=98_SLA_Book_Club:_Zikora_b...
# 4      Flash Points: U.S. election violence is a clea...
# 5                                Debit Alert: XXXXXX5010
# ...                                                  ...
# 30103                            Debit Alert: XXXXXX5010
# 30104                             Google Alert - Fashion
# 30105  There's A New Kind Of Inequality. And It's Not...
# 30106                      Google Alert - New technology
# 30107                 Ho Africa Tv just uploaded a video
#
#                                                     from  \
# 1                           ALATbyWema <noreply@alat.ng>
# 2      =?utf-8?Q?Fashionista?= <newsletters@fashionis...
# 3          She Leads Africa <content@sheleadsafrica.org>
# 4         Foreign Policy <noreply@crm.foreignpolicy.com>
# 5                            "FCMB" <ebusiness@fcmb.com>
# ...                                                  ...
# 30103                        "FCMB" <ebusiness@fcmb.com>
# 30104    Google Alerts <googlealerts-noreply@google.com>
# 30105                   "Pocket" <noreply@getpocket.com>
# 30106    Google Alerts <googlealerts-noreply@google.com>
# 30107                      YouTube <noreply@youtube.com>
#
#                            date  \
# 1     2020-10-31 11:02:45+00:00
# 2     2020-11-03 16:59:46+00:00
# 3     2020-10-31 17:08:31+00:00
# 4     2020-10-30 13:12:41+00:00
# 5     2020-10-30 11:06:41+00:00
# ...                         ...
# 30103 2020-01-17 18:27:08+00:00
# 30104 2020-07-24 07:04:33+00:00
# 30105 2019-12-10 18:24:39+00:00
# 30106 2020-10-26 20:00:07+00:00
# 30107 2020-03-26 04:33:07+00:00
#
#                                                       to  \
# 1                            victoriousjvictor@gmail.com
# 2                          <victoriousjvictor@gmail.com>
# 3                            victoriousjvictor@gmail.com
# 4      "victoriousjvictor@gmail.com" <victoriousjvict...
# 5                            victoriousjvictor@gmail.com
# ...                                                  ...
# 30103                        victoriousjvictor@gmail.com
# 30104                        victoriousjvictor@gmail.com
# 30105                        victoriousjvictor@gmail.com
# 30106                        victoriousjvictor@gmail.com
# 30107                        victoriousjvictor@gmail.com
#
#                                   label               thread
# 1         Inbox,Category Updates,Unread  1682064975966880594
# 2      Inbox,Category Promotions,Unread  1682359422775130217
# 3         Inbox,Category Updates,Unread  1682087987251912700
# 4         Inbox,Category Updates,Unread  1681982557987556596
# 5        Inbox,Category Personal,Unread  1681974518294368770
# ...                                 ...                  ...
# 30103     Inbox,Category Updates,Unread  1656001007669102716
# 30104     Inbox,Category Updates,Unread  1673080890461859067
# 30105  Inbox,Category Promotions,Unread  1652558801022797654
# 30106     Inbox,Category Updates,Unread  1681645799109025785
# 30107      Inbox,Category Social,Unread  1662199726993116734
#
# [30107 rows x 6 columns]

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30107 entries, 1 to 30107
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   subject  30096 non-null  object
#  1   from     30107 non-null  object
#  2   date     30107 non-null  datetime64[ns, UTC]
#  3   to       30099 non-null  object
#  4   label    30107 non-null  object
#  5   thread   30107 non-null  object
# dtypes: datetime64[ns, UTC](1), object(5)
# memory usage: 1.6+ MB

# %%
dfs.columns
# Out:
# Index(['subject', 'from', 'date', 'to', 'label', 'thread'], dtype='object')

# %%
# using regex to pick out only email addresses from dfs["from"]


import re

def extract_email_ID(string):
  email = re.findall(r'<(.+?)>', string)  # check the string and search if it contains <....>
  if not email:
    email = list(filter(lambda y: '@' in y, string.split()))  # lamba function to check if the string contains @
  return email[0] if email else np.nan  # if it doesn't contain @ return nan else the email address is returned


# applying the function to the dataframe
dfs['from'] = dfs['from'].apply(lambda x: extract_email_ID(x))

# %%
#output of the extract_email_ID function

dfs
# Out:
#                                                  subject  \
# 1      =?UTF-8?Q?Joy,_Save_=E2=82=A650,000_Off_Your_S...
# 2      =?utf-8?Q?19=20Gifts=20for=20Your=20=27Emily=2...
# 3      =?utf-8?Q?=F0=9F=93=98_SLA_Book_Club:_Zikora_b...
# 4      Flash Points: U.S. election violence is a clea...
# 5                                Debit Alert: XXXXXX5010
# ...                                                  ...
# 30103                            Debit Alert: XXXXXX5010
# 30104                             Google Alert - Fashion
# 30105  There's A New Kind Of Inequality. And It's Not...
# 30106                      Google Alert - New technology
# 30107                 Ho Africa Tv just uploaded a video
#
#                                   from                      date  \
# 1                      noreply@alat.ng 2020-10-31 11:02:45+00:00
# 2          newsletters@fashionista.com 2020-11-03 16:59:46+00:00
# 3           content@sheleadsafrica.org 2020-10-31 17:08:31+00:00
# 4        noreply@crm.foreignpolicy.com 2020-10-30 13:12:41+00:00
# 5                   ebusiness@fcmb.com 2020-10-30 11:06:41+00:00
# ...                                ...                       ...
# 30103               ebusiness@fcmb.com 2020-01-17 18:27:08+00:00
# 30104  googlealerts-noreply@google.com 2020-07-24 07:04:33+00:00
# 30105            noreply@getpocket.com 2019-12-10 18:24:39+00:00
# 30106  googlealerts-noreply@google.com 2020-10-26 20:00:07+00:00
# 30107              noreply@youtube.com 2020-03-26 04:33:07+00:00
#
#                                                       to  \
# 1                            victoriousjvictor@gmail.com
# 2                          <victoriousjvictor@gmail.com>
# 3                            victoriousjvictor@gmail.com
# 4      "victoriousjvictor@gmail.com" <victoriousjvict...
# 5                            victoriousjvictor@gmail.com
# ...                                                  ...
# 30103                        victoriousjvictor@gmail.com
# 30104                        victoriousjvictor@gmail.com
# 30105                        victoriousjvictor@gmail.com
# 30106                        victoriousjvictor@gmail.com
# 30107                        victoriousjvictor@gmail.com
#
#                                   label               thread
# 1         Inbox,Category Updates,Unread  1682064975966880594
# 2      Inbox,Category Promotions,Unread  1682359422775130217
# 3         Inbox,Category Updates,Unread  1682087987251912700
# 4         Inbox,Category Updates,Unread  1681982557987556596
# 5        Inbox,Category Personal,Unread  1681974518294368770
# ...                                 ...                  ...
# 30103     Inbox,Category Updates,Unread  1656001007669102716
# 30104     Inbox,Category Updates,Unread  1673080890461859067
# 30105  Inbox,Category Promotions,Unread  1652558801022797654
# 30106     Inbox,Category Updates,Unread  1681645799109025785
# 30107      Inbox,Category Social,Unread  1662199726993116734
#
# [30107 rows x 6 columns]

# %%
# refactoring timezones to do proper analysis

# %%
import datetime
import pytz   # python module used to change time zones accurately

def refactor_timezone(x):
    gmt_1 = pytz.timezone('Africa/Lagos') # my time zone. Please note, other time zones exist
    return x.astimezone(gmt_1)

# %%
dfs['date'] = dfs['date'].apply(lambda x: refactor_timezone(x))  # applying the timezone to the dataframe

# %%
dfs
# Out:
#                                                  subject  \
# 1      =?UTF-8?Q?Joy,_Save_=E2=82=A650,000_Off_Your_S...
# 2      =?utf-8?Q?19=20Gifts=20for=20Your=20=27Emily=2...
# 3      =?utf-8?Q?=F0=9F=93=98_SLA_Book_Club:_Zikora_b...
# 4      Flash Points: U.S. election violence is a clea...
# 5                                Debit Alert: XXXXXX5010
# ...                                                  ...
# 30103                            Debit Alert: XXXXXX5010
# 30104                             Google Alert - Fashion
# 30105  There's A New Kind Of Inequality. And It's Not...
# 30106                      Google Alert - New technology
# 30107                 Ho Africa Tv just uploaded a video
#
#                                   from                      date  \
# 1                      noreply@alat.ng 2020-10-31 12:02:45+01:00
# 2          newsletters@fashionista.com 2020-11-03 17:59:46+01:00
# 3           content@sheleadsafrica.org 2020-10-31 18:08:31+01:00
# 4        noreply@crm.foreignpolicy.com 2020-10-30 14:12:41+01:00
# 5                   ebusiness@fcmb.com 2020-10-30 12:06:41+01:00
# ...                                ...                       ...
# 30103               ebusiness@fcmb.com 2020-01-17 19:27:08+01:00
# 30104  googlealerts-noreply@google.com 2020-07-24 08:04:33+01:00
# 30105            noreply@getpocket.com 2019-12-10 19:24:39+01:00
# 30106  googlealerts-noreply@google.com 2020-10-26 21:00:07+01:00
# 30107              noreply@youtube.com 2020-03-26 05:33:07+01:00
#
#                                                       to  \
# 1                            victoriousjvictor@gmail.com
# 2                          <victoriousjvictor@gmail.com>
# 3                            victoriousjvictor@gmail.com
# 4      "victoriousjvictor@gmail.com" <victoriousjvict...
# 5                            victoriousjvictor@gmail.com
# ...                                                  ...
# 30103                        victoriousjvictor@gmail.com
# 30104                        victoriousjvictor@gmail.com
# 30105                        victoriousjvictor@gmail.com
# 30106                        victoriousjvictor@gmail.com
# 30107                        victoriousjvictor@gmail.com
#
#                                   label               thread
# 1         Inbox,Category Updates,Unread  1682064975966880594
# 2      Inbox,Category Promotions,Unread  1682359422775130217
# 3         Inbox,Category Updates,Unread  1682087987251912700
# 4         Inbox,Category Updates,Unread  1681982557987556596
# 5        Inbox,Category Personal,Unread  1681974518294368770
# ...                                 ...                  ...
# 30103     Inbox,Category Updates,Unread  1656001007669102716
# 30104     Inbox,Category Updates,Unread  1673080890461859067
# 30105  Inbox,Category Promotions,Unread  1652558801022797654
# 30106     Inbox,Category Updates,Unread  1681645799109025785
# 30107      Inbox,Category Social,Unread  1662199726993116734
#
# [30107 rows x 6 columns]

# %%
# dropping "to" feature because all mails were sent to me. duh!!!

dfs.drop("to", axis = 1, inplace = True)

# %%
dfs
# Out:
#                                                  subject  \
# 1      =?UTF-8?Q?Joy,_Save_=E2=82=A650,000_Off_Your_S...
# 2      =?utf-8?Q?19=20Gifts=20for=20Your=20=27Emily=2...
# 3      =?utf-8?Q?=F0=9F=93=98_SLA_Book_Club:_Zikora_b...
# 4      Flash Points: U.S. election violence is a clea...
# 5                                Debit Alert: XXXXXX5010
# ...                                                  ...
# 30103                            Debit Alert: XXXXXX5010
# 30104                             Google Alert - Fashion
# 30105  There's A New Kind Of Inequality. And It's Not...
# 30106                      Google Alert - New technology
# 30107                 Ho Africa Tv just uploaded a video
#
#                                   from                      date  \
# 1                      noreply@alat.ng 2020-10-31 12:02:45+01:00
# 2          newsletters@fashionista.com 2020-11-03 17:59:46+01:00
# 3           content@sheleadsafrica.org 2020-10-31 18:08:31+01:00
# 4        noreply@crm.foreignpolicy.com 2020-10-30 14:12:41+01:00
# 5                   ebusiness@fcmb.com 2020-10-30 12:06:41+01:00
# ...                                ...                       ...
# 30103               ebusiness@fcmb.com 2020-01-17 19:27:08+01:00
# 30104  googlealerts-noreply@google.com 2020-07-24 08:04:33+01:00
# 30105            noreply@getpocket.com 2019-12-10 19:24:39+01:00
# 30106  googlealerts-noreply@google.com 2020-10-26 21:00:07+01:00
# 30107              noreply@youtube.com 2020-03-26 05:33:07+01:00
#
#                                   label               thread
# 1         Inbox,Category Updates,Unread  1682064975966880594
# 2      Inbox,Category Promotions,Unread  1682359422775130217
# 3         Inbox,Category Updates,Unread  1682087987251912700
# 4         Inbox,Category Updates,Unread  1681982557987556596
# 5        Inbox,Category Personal,Unread  1681974518294368770
# ...                                 ...                  ...
# 30103     Inbox,Category Updates,Unread  1656001007669102716
# 30104     Inbox,Category Updates,Unread  1673080890461859067
# 30105  Inbox,Category Promotions,Unread  1652558801022797654
# 30106     Inbox,Category Updates,Unread  1681645799109025785
# 30107      Inbox,Category Social,Unread  1662199726993116734
#
# [30107 rows x 5 columns]

# %%
# creating a new feature to show if the the mail is from me or not

myemail = 'victoriousjvictor@gmail.com'
dfs['label'] = dfs['from'].apply(lambda x: 'sent' if x==myemail else 'inbox')

dfs.head(50)  # checking to see if it actually works and it did
# Out:
#                                               subject  \
# 1   =?UTF-8?Q?Joy,_Save_=E2=82=A650,000_Off_Your_S...
# 2   =?utf-8?Q?19=20Gifts=20for=20Your=20=27Emily=2...
# 3   =?utf-8?Q?=F0=9F=93=98_SLA_Book_Club:_Zikora_b...
# 4   Flash Points: U.S. election violence is a clea...
# 5                             Debit Alert: XXXXXX5010
# 6                             Debit Alert: XXXXXX5010
# 7                             Debit Alert: XXXXXX5010
# 8   =?utf-8?Q?The=20Complicated=20Legacy=20of=20=2...
# 9                            Credit Alert: XXXXXX5010
# 10  Joy, you can still do something for your future!!
# 11                Caroline and Ann are fighting back!
# 12    Firebase Summit 2020: Tune into the livestream!
# 13  The Overflow #45: What we call CI/CD is actual...
# 14                                         Meet Casey
# 15                           Credit Alert: XXXXXX5010
# 16                           Credit Alert: XXXXXX5010
# 17                           Credit Alert: XXXXXX5010
# 18                           Credit Alert: XXXXXX5010
# 19                           Credit Alert: XXXXXX5010
# 20                    Free pandemic response training
# 21                              Help getting started?
# 22  =?utf-8?q?What_programming_languages_do_softwa...
# 23                      Google Alert - New technology
# 24  OCTOBER BIBLE STUDY OUTLINE AND PREP CLASS NOW...
# 25  Study in Germany: Timeline for September Intak...
# 26         GitHub Explore the week of Oct 20 - Oct 27
# 27      Recommended: Google IT Automation with Python
# 28  =?utf-8?Q?ICYMI=3A=C2=A0The=2023=20Best=20Thin...
# 29        Michigan State University Scholarships 2020
# 30  Be A Part Of Today's LIVE Broadcast - Your Lov...
# 31         GitHub Explore the week of Oct 13 - Oct 20
# 32  Editors' Picks: COVID-19 might not change the ...
# 33                      Google Alert - New technology
# 34  The 2020 Revolutions: Be a part of #ShutItAllD...
# 35  Notifications & Updates for You: Cool New Feat...
# 36                Google Alert - Computer Programming
# 37                            Debit Alert: XXXXXX5010
# 38                            Debit Alert: XXXXXX5010
# 39                            Debit Alert: XXXXXX5010
# 40                            Debit Alert: XXXXXX5010
# 41                            Debit Alert: XXXXXX5010
# 42                            Debit Alert: XXXXXX5010
# 43                            Debit Alert: XXXXXX5010
# 44                            Debit Alert: XXXXXX5010
# 45   Webinar Tomorrow: Working with Data in the Cloud
# 46                                   MTNF Scholarship
# 47                     Notice of Id-el-Maulud Holiday
# 48                           Credit Alert: XXXXXX5010
# 49                             Google Alert - Fashion
# 50                              HEALING SCHOOL WEEKLY
#
#                                    from                      date  label  \
# 1                       noreply@alat.ng 2020-10-31 12:02:45+01:00  inbox
# 2           newsletters@fashionista.com 2020-11-03 17:59:46+01:00  inbox
# 3            content@sheleadsafrica.org 2020-10-31 18:08:31+01:00  inbox
# 4         noreply@crm.foreignpolicy.com 2020-10-30 14:12:41+01:00  inbox
# 5                    ebusiness@fcmb.com 2020-10-30 12:06:41+01:00  inbox
# 6                    ebusiness@fcmb.com 2020-10-30 12:06:32+01:00  inbox
# 7                    ebusiness@fcmb.com 2020-10-30 12:04:50+01:00  inbox
# 8           newsletters@fashionista.com 2020-10-30 16:59:52+01:00  inbox
# 9                    ebusiness@fcmb.com 2020-11-03 16:36:07+01:00  inbox
# 10                   mary@astromary.com 2020-10-31 03:25:37+01:00  inbox
# 11           petitions-en@citizengo.org 2020-11-02 09:29:27+01:00  inbox
# 12           firebase-summit@google.com 2020-10-27 17:22:16+01:00  inbox
# 13     do-not-reply@stackoverflow.email 2020-10-28 10:05:37+01:00  inbox
# 14            qazi@cleverprogrammer.com 2020-10-26 18:07:08+01:00  inbox
# 15                   ebusiness@fcmb.com 2020-10-30 16:57:23+01:00  inbox
# 16                   ebusiness@fcmb.com 2020-10-30 15:53:08+01:00  inbox
# 17                   ebusiness@fcmb.com 2020-10-30 15:36:15+01:00  inbox
# 18                   ebusiness@fcmb.com 2020-10-30 10:54:57+01:00  inbox
# 19                   ebusiness@fcmb.com 2020-10-30 10:11:52+01:00  inbox
# 20          Coursera@email.coursera.org 2020-10-29 22:29:24+01:00  inbox
# 21                  sandeep@hashnode.co 2020-10-29 09:54:48+01:00  inbox
# 22     english-digest-noreply@quora.com 2020-10-26 03:58:07+01:00  inbox
# 23      googlealerts-noreply@google.com 2020-10-15 21:13:00+01:00  inbox
# 24                 info@ceclfonline.org 2020-10-12 04:23:11+01:00  inbox
# 25         noreply+feedproxy@google.com 2020-10-13 13:55:25+01:00  inbox
# 26                   noreply@github.com 2020-10-27 09:35:48+01:00  inbox
# 27         no-reply@m.mail.coursera.org 2020-10-12 21:52:11+01:00  inbox
# 28          newsletters@fashionista.com 2020-11-01 17:59:42+01:00  inbox
# 29         noreply+feedproxy@google.com 2020-11-02 13:50:36+01:00  inbox
# 30  noreply@n.enterthehealingschool.org 2020-10-28 19:08:12+01:00  inbox
# 31                   noreply@github.com 2020-10-20 09:30:42+01:00  inbox
# 32        noreply@crm.foreignpolicy.com 2020-10-10 22:57:19+01:00  inbox
# 33      googlealerts-noreply@google.com 2020-10-08 21:02:49+01:00  inbox
# 34           content@sheleadsafrica.org 2020-10-12 18:05:52+01:00  inbox
# 35                  info@realpython.com 2020-10-06 17:17:51+01:00  inbox
# 36      googlealerts-noreply@google.com 2020-10-16 22:02:24+01:00  inbox
# 37                   ebusiness@fcmb.com 2020-10-28 21:09:29+01:00  inbox
# 38                   ebusiness@fcmb.com 2020-10-28 12:19:54+01:00  inbox
# 39                   ebusiness@fcmb.com 2020-10-28 12:19:40+01:00  inbox
# 40                   ebusiness@fcmb.com 2020-10-28 10:15:34+01:00  inbox
# 41                   ebusiness@fcmb.com 2020-10-28 07:41:01+01:00  inbox
# 42                   ebusiness@fcmb.com 2020-10-28 05:58:23+01:00  inbox
# 43                   ebusiness@fcmb.com 2020-10-28 05:58:23+01:00  inbox
# 44                   ebusiness@fcmb.com 2020-10-28 03:44:17+01:00  inbox
# 45              ambassador@anaconda.com 2020-10-27 17:14:04+01:00  inbox
# 46          victoriousjvictor@gmail.com 2020-09-28 16:17:22+01:00   sent
# 47                  notify@wemabank.com 2020-10-28 12:02:33+01:00  inbox
# 48                   ebusiness@fcmb.com 2020-09-28 09:24:26+01:00  inbox
# 49      googlealerts-noreply@google.com 2020-11-01 08:01:34+01:00  inbox
# 50  noreply@n.enterthehealingschool.org 2020-10-13 21:29:14+01:00  inbox
#
#                  thread
# 1   1682064975966880594
# 2   1682359422775130217
# 3   1682087987251912700
# 4   1681982557987556596
# 5   1681974518294368770
# 6   1681974518294368770
# 7   1681974518294368770
# 8   1681993458151248157
# 9   1682353967689599723
# 10  1682032441188755972
# 11  1682237963001539247
# 12  1681722689781274111
# 13  1681785815638872292
# 14  1681634917311862694
# 15  1681967403800232045
# 16  1681967403800232045
# 17  1681967403800232045
# 18  1681967403800232045
# 19  1681967403800232045
# 20  1681923213996384950
# 21  1681875732322165302
# 22  1681581504306029960
# 23  1680650043165770558
# 24  1680314757502488084
# 25  1680441318954671019
# 26  1681693343024417858
# 27  1680380717455367594
# 28  1682178151829189874
# 29  1682252955768728698
# 30  1681819952796964401
# 31  1681058852592480007
# 32  1680203667858768447
# 33  1680015225095117172
# 34  1680366477911969165
# 35  1679819881650635820
# 36  1680743748760902854
# 37  1681761840420570106
# 38  1681761840420570106
# 39  1681761840420570106
# 40  1681761840420570106
# 41  1681761840420570106
# 42  1681761840420570106
# 43  1681761840420570106
# 44  1681761840420570106
# 45  1681722182176342672
# 46  1679091082286047782
# 47  1681793173244624511
# 48  1679065322347529160
# 49  1682140399144090056
# 50  1680469871656003619
